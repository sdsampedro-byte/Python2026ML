# %% [markdown]
# <h2 style="text-align: center;"> IMPUTACIÓN DE DATOS AUSENTES </h2>
#
# <img src="img/ITQ.jpg" width="1000">
#
# **Nombre:** *Sebastian Sampedro* <br>
# **Fecha:** *7/5/2026* <br>
# **Link Github:** "https://github.com/sdsampedro-byte/Python2026ML"

# %%
import numpy as np
from sklearn.impute import SimpleImputer

# %%
# Carga de datos
X_train = [[1,      4], 
           [np.nan, 3], 
           [7,      8]]

# %%
# Limpieza de datos: imputación valores ausentes (modelo)
imputer = SimpleImputer(strategy='mean') # Utilizamos la estrategia de la media

# Aplicar los métodos "fit" y "transform" para imputar los valores pérdidos de X_train
X_train_clean = imputer.fit_transform(X_train)
print(X_train_clean)
# Out:
# [[1. 4.]
#  [4. 3.]
#  [7. 8.]]

# %%
# Imputación de valores ausentes sobre el conjunto de test
X_test = [[np.nan, 10], 
          [6,      np.nan], 
          [8,      2]]

# Imputar los datos del conjunto de test
X_test_clean=imputer.transform(X_test)
print(X_test_clean)
# Out:
# [[ 4. 10.]
#  [ 6.  5.]
#  [ 8.  2.]]
